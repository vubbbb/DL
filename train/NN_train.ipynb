# %% [markdown]
# CHUẨN BỊ DỮ LIỆU

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_path = 'D:/HK1 2024 2025/Deep Learning/BTL/Final/dataset/train'
test_path = 'D:/HK1 2024 2025/Deep Learning/BTL/Final/dataset/test'
validation_path = 'D:/HK1 2024 2025/Deep Learning/BTL/Final/dataset/validate'

train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_path,
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_path,
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 2122 images belonging to 3 classes.
# Found 269 images belonging to 3 classes.
# Found 264 images belonging to 3 classes.

# %% [markdown]
# Mô hình mạng neuron đơn giản

# %%
from tensorflow.keras import models, layers, optimizers

def build_simple_nn():
    model = models.Sequential()
    model.add(layers.Flatten(input_shape=(128, 128, 3)))
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(3, activation='softmax')) # 3 classes
    
    optimizer = optimizers.Adam(learning_rate=0.01)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

model_1 = build_simple_nn()
model_1.summary()
# Out:
# c:\Users\tranb\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 49152)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     6,291,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,300,035 (24.03 MB)
#  Trainable params: 6,300,035 (24.03 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_1 = model_1.fit(
    train_generator,
    epochs=10,
    validation_data=validation_generator
)
score = model_1.evaluate(test_generator)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Epoch 1/10
# c:\Users\tranb\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.4007 - loss: 85.9073 - val_accuracy: 0.8253 - val_loss: 0.9771
# Epoch 2/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.8882 - loss: 0.5400 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 3/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 8s 110ms/step - accuracy: 0.9943 - loss: 0.0233 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 4/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 7s 110ms/step - accuracy: 0.9966 - loss: 0.0202 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 5/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 8s 118ms/step - accuracy: 0.9859 - loss: 0.0501 - val_accuracy: 0.9777 - val_loss: 0.0638
# Epoch 6/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 8s 114ms/step - accuracy: 0.9810 - loss: 0.0716 - val_accuracy: 1.0000 - val_loss: 1.7448e-04
# Epoch 7/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 8s 111ms/step - accuracy: 0.9965 - loss: 0.0106 - val_accuracy: 1.0000 - val_loss: 9.2809e-04
# Epoch 8/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 8s 123ms/step - accuracy: 0.9928 - loss: 0.0316 - val_accuracy: 0.9963 - val_loss: 0.0085
# Epoch 9/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 8s 119ms/step - accuracy: 0.9952 - loss: 0.0120 - val_accuracy: 1.0000 - val_loss: 1.7945e-04
# Epoch 10/10
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9997 - loss: 9.9012e-04 - val_accuracy: 1.0000 - val_loss: 9.0258e-04
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 3.4570e-04
# Test loss: 0.0004631264600902796
# Test accuracy: 1.0

# %%
import matplotlib.pyplot as plt

def plot_history(history, model_name):
    # Kiểm tra kích thước của các biến
    print(f'Epochs: {len(history_1.history["accuracy"])}')
    print(f'Training Accuracy: {len(history_1.history["accuracy"])}')
    print(f'Validation Accuracy: {len(history_1.history["val_accuracy"])}')
    epochs = range(1, len(history.history['accuracy']) + 1)
    
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    
    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'b', label='Training accuracy')
    plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
    plt.title(f'{model_name} - Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    # Vẽ đồ thị Loss nếu có
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'b', label='Training loss')
    plt.plot(epochs, val_loss, 'r', label='Validation loss')
    plt.title(f'{model_name} - Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.show()


# Vẽ đồ thị cho model_1
plot_history(history_1, 'Simple NN')
# Out:
# Epochs: 10
# Training Accuracy: 10
# Validation Accuracy: 10

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def plot_confusion_matrix_heatmap(test_generator, model, class_labels):
    # Get true labels and predicted labels
    true_labels = []
    predicted_labels = []

    # Loop through the entire test set
    for i in range(len(test_generator)):
        # Get a batch of images and labels
        images, labels = test_generator[i]

        # Predict using the model
        predictions = model.predict(images)

        # For multi-class classification, use np.argmax to get the predicted class
        predicted_class = np.argmax(predictions, axis=-1)
        true_class = np.argmax(labels, axis=-1)

        # Append the true and predicted labels
        true_labels.extend(true_class)
        predicted_labels.extend(predicted_class)
    
    # Generate confusion matrix
    cm = confusion_matrix(true_labels, predicted_labels)

    # Plot the confusion matrix as a heatmap
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix Heatmap')
    plt.show()

    return cm

# %%
# Assuming 'model' is your trained CNN model and 'test_generator' is your test data generator
class_labels = list(test_generator.class_indices.keys())

# Plot the confusion matrix heatmap
confusion_matrix = plot_confusion_matrix_heatmap(test_generator, model_1, class_labels)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step

# %%
# # Lưu trữ mô hình huấn luyện
model_1.save('D:/HK1 2024 2025/Deep Learning/BTL/Final/models/simple_NN.keras')  # Lưu mô hình vào file .h5

# %%
from tensorflow.keras.preprocessing import image
import random
import numpy as np
import matplotlib.pyplot as plt

# Danh sách nhãn tương ứng với các lớp
label_map = ['A', 'B', 'C']

# Chọn ngẫu nhiên 1 chỉ số ảnh từ tập kiểm tra
random_index = random.choice(range(len(test_generator)))

# Lấy ảnh và nhãn thật từ test_generator
test_images, test_labels = test_generator[random_index]

# Dự đoán cho ảnh ngẫu nhiên
predictions = model_1.predict(test_images)
predicted_class_index = np.argmax(predictions[0])  # Chọn lớp có xác suất cao nhất
true_class_index = np.argmax(test_labels[0])  # Nhãn thật

# Chuyển nhãn số thành nhãn chữ
predicted_class = label_map[predicted_class_index]
true_class = label_map[true_class_index]

# Hiển thị kết quả
plt.imshow(test_images[0])  # Hiển thị ảnh
plt.title(f'True Class: {true_class}, Predicted Class: {predicted_class}')
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
